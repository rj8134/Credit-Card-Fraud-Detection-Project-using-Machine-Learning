# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("credit-card.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0           0      50000    1          2         1   57     -1      0     -1
# 1           1      50000    1          1         2   37      0      0      0
# 2           2     500000    1          1         2   29      0      0      0
# 3           3     100000    2          2         2   23      0     -1     -1
# 4           4     140000    2          3         1   28      0      0      2
#
#    PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      20940      19146      19131      2000     36681     10000
# 1      0  ...      19394      19619      20024      2500      1815       657
# 2      0  ...     542653     483003     473944     55000     40000     38000
# 3      0  ...        221       -159        567       380       601         0
# 4      0  ...      12211      11793       3719      3329         0       432
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0      9000       689       679                           0
# 1      1000      1000       800                           0
# 2     20239     13750     13770                           0
# 3       581      1687      1542                           0
# 4      1000      1000      1000                           0
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1',
#        'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
#        'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  1001 non-null   int64
#  1   LIMIT_BAL                   1001 non-null   int64
#  2   SEX                         1001 non-null   int64
#  3   EDUCATION                   1001 non-null   int64
#  4   MARRIAGE                    1001 non-null   int64
#  5   AGE                         1001 non-null   int64
#  6   PAY_0                       1001 non-null   int64
#  7   PAY_2                       1001 non-null   int64
#  8   PAY_3                       1001 non-null   int64
#  9   PAY_4                       1001 non-null   int64
#  10  PAY_5                       1001 non-null   int64
#  11  PAY_6                       1001 non-null   int64
#  12  BILL_AMT1                   1001 non-null   int64
#  13  BILL_AMT2                   1001 non-null   int64
#  14  BILL_AMT3                   1001 non-null   int64
#  15  BILL_AMT4                   1001 non-null   int64
#  16  BILL_AMT5                   1001 non-null   int64
#  17  BILL_AMT6                   1001 non-null   int64
#  18  PAY_AMT1                    1001 non-null   int64
#  19  PAY_AMT2                    1001 non-null   int64
#  20  PAY_AMT3                    1001 non-null   int64
#  21  PAY_AMT4                    1001 non-null   int64
#  22  PAY_AMT5                    1001 non-null   int64
#  23  PAY_AMT6                    1001 non-null   int64
#  24  default payment next month  1001 non-null   int64
# dtypes: int64(25)
# memory usage: 195.6 KB

# %%
df.shape
# Out:
# (1001, 25)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, LIMIT_BAL, SEX, EDUCATION, MARRIAGE, AGE, PAY_0, PAY_2, PAY_3, PAY_4, PAY_5, PAY_6, BILL_AMT1, BILL_AMT2, BILL_AMT3, BILL_AMT4, BILL_AMT5, BILL_AMT6, PAY_AMT1, PAY_AMT2, PAY_AMT3, PAY_AMT4, PAY_AMT5, PAY_AMT6, default payment next month]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.describe()
# Out:
#         Unnamed: 0      LIMIT_BAL          SEX    EDUCATION     MARRIAGE  \
# count  1001.000000    1001.000000  1001.000000  1001.000000  1001.000000
# mean    500.000000  167532.467532     1.589411     1.776224     1.604396
# std     289.108111  130587.921320     0.492187     0.750916     0.532298
# min       0.000000   10000.000000     1.000000     1.000000     0.000000
# 25%     250.000000   50000.000000     1.000000     1.000000     1.000000
# 50%     500.000000  140000.000000     2.000000     2.000000     2.000000
# 75%     750.000000  240000.000000     2.000000     2.000000     2.000000
# max    1000.000000  700000.000000     2.000000     6.000000     3.000000
#
#                AGE        PAY_0        PAY_2        PAY_3        PAY_4  ...  \
# count  1001.000000  1001.000000  1001.000000  1001.000000  1001.000000  ...
# mean     34.945055    -0.004995    -0.161838    -0.164835    -0.283716  ...
# std       9.219760     1.173446     1.228732     1.262459     1.184662  ...
# min      21.000000    -2.000000    -2.000000    -2.000000    -2.000000  ...
# 25%      28.000000    -1.000000    -1.000000    -1.000000    -1.000000  ...
# 50%      33.000000     0.000000     0.000000     0.000000     0.000000  ...
# 75%      41.000000     0.000000     0.000000     0.000000     0.000000  ...
# max      75.000000     8.000000     7.000000     7.000000     7.000000  ...
#
#            BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count    1001.000000    1001.000000    1001.000000    1001.000000
# mean    40748.408591   39078.666334   38012.011988    5382.339660
# std     68206.929510   63108.238729   63074.415024   12180.755275
# min     -3684.000000  -28335.000000 -339603.000000       0.000000
# 25%      1423.000000    1206.000000     830.000000    1000.000000
# 50%     17710.000000   17580.000000   15846.000000    2184.000000
# 75%     48851.000000   46404.000000   46557.000000    5090.000000
# max    628699.000000  484612.000000  473944.000000  199646.000000
#
#             PAY_AMT2       PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count    1001.000000    1001.000000    1001.000000    1001.000000
# mean     5051.400599    4176.149850    4671.488511    5331.049950
# std     15626.153184   10514.647502   13269.943983   16812.536877
# min         0.000000       0.000000       0.000000       0.000000
# 25%       390.000000     228.000000     148.000000     189.000000
# 50%      1710.000000    1206.000000    1398.000000    1306.000000
# 75%      4500.000000    3720.000000    4000.000000    3745.000000
# max    285138.000000  133657.000000  188840.000000  195599.000000
#
#             PAY_AMT6  default payment next month
# count    1001.000000                 1001.000000
# mean     5090.704296                    0.213786
# std     23658.888052                    0.410183
# min         0.000000                    0.000000
# 25%         0.000000                    0.000000
# 50%      1250.000000                    0.000000
# 75%      3784.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 25 columns]

# %%
df.describe().T
# Out:
#                              count           mean            std       min  \
# Unnamed: 0                  1001.0     500.000000     289.108111       0.0
# LIMIT_BAL                   1001.0  167532.467532  130587.921320   10000.0
# SEX                         1001.0       1.589411       0.492187       1.0
# EDUCATION                   1001.0       1.776224       0.750916       1.0
# MARRIAGE                    1001.0       1.604396       0.532298       0.0
# AGE                         1001.0      34.945055       9.219760      21.0
# PAY_0                       1001.0      -0.004995       1.173446      -2.0
# PAY_2                       1001.0      -0.161838       1.228732      -2.0
# PAY_3                       1001.0      -0.164835       1.262459      -2.0
# PAY_4                       1001.0      -0.283716       1.184662      -2.0
# PAY_5                       1001.0      -0.283716       1.170224      -2.0
# PAY_6                       1001.0      -0.314685       1.203276      -2.0
# BILL_AMT1                   1001.0   49386.738262   72657.966256  -14386.0
# BILL_AMT2                   1001.0   47879.345654   72090.718188  -13543.0
# BILL_AMT3                   1001.0   44925.682318   69545.948045   -9850.0
# BILL_AMT4                   1001.0   40748.408591   68206.929510   -3684.0
# BILL_AMT5                   1001.0   39078.666334   63108.238729  -28335.0
# BILL_AMT6                   1001.0   38012.011988   63074.415024 -339603.0
# PAY_AMT1                    1001.0    5382.339660   12180.755275       0.0
# PAY_AMT2                    1001.0    5051.400599   15626.153184       0.0
# PAY_AMT3                    1001.0    4176.149850   10514.647502       0.0
# PAY_AMT4                    1001.0    4671.488511   13269.943983       0.0
# PAY_AMT5                    1001.0    5331.049950   16812.536877       0.0
# PAY_AMT6                    1001.0    5090.704296   23658.888052       0.0
# default payment next month  1001.0       0.213786       0.410183       0.0
#
#                                 25%       50%       75%       max
# Unnamed: 0                    250.0     500.0     750.0    1000.0
# LIMIT_BAL                   50000.0  140000.0  240000.0  700000.0
# SEX                             1.0       2.0       2.0       2.0
# EDUCATION                       1.0       2.0       2.0       6.0
# MARRIAGE                        1.0       2.0       2.0       3.0
# AGE                            28.0      33.0      41.0      75.0
# PAY_0                          -1.0       0.0       0.0       8.0
# PAY_2                          -1.0       0.0       0.0       7.0
# PAY_3                          -1.0       0.0       0.0       7.0
# PAY_4                          -1.0       0.0       0.0       7.0
# PAY_5                          -1.0       0.0       0.0       7.0
# PAY_6                          -1.0       0.0       0.0       7.0
# BILL_AMT1                    3128.0   21075.0   59901.0  507726.0
# BILL_AMT2                    3274.0   20400.0   58472.0  509229.0
# BILL_AMT3                    1940.0   19292.0   54477.0  499936.0
# BILL_AMT4                    1423.0   17710.0   48851.0  628699.0
# BILL_AMT5                    1206.0   17580.0   46404.0  484612.0
# BILL_AMT6                     830.0   15846.0   46557.0  473944.0
# PAY_AMT1                     1000.0    2184.0    5090.0  199646.0
# PAY_AMT2                      390.0    1710.0    4500.0  285138.0
# PAY_AMT3                      228.0    1206.0    3720.0  133657.0
# PAY_AMT4                      148.0    1398.0    4000.0  188840.0
# PAY_AMT5                      189.0    1306.0    3745.0  195599.0
# PAY_AMT6                        0.0    1250.0    3784.0  528666.0
# default payment next month      0.0       0.0       0.0       1.0

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
# sns.pairplot(df)

# %%
df.skew()
# Out:
# Unnamed: 0                     0.000000
# LIMIT_BAL                      1.011019
# SEX                           -0.364047
# EDUCATION                      0.875019
# MARRIAGE                      -0.104653
# AGE                            0.817570
# PAY_0                          1.509158
# PAY_2                          1.208410
# PAY_3                          1.226851
# PAY_4                          1.217037
# PAY_5                          1.053218
# PAY_6                          1.064620
# BILL_AMT1                      2.671027
# BILL_AMT2                      2.777126
# BILL_AMT3                      2.901497
# BILL_AMT4                      3.578203
# BILL_AMT5                      3.107180
# BILL_AMT6                      2.636691
# PAY_AMT1                       7.749893
# PAY_AMT2                      10.752948
# PAY_AMT3                       6.744377
# PAY_AMT4                       7.454775
# PAY_AMT5                       7.034632
# PAY_AMT6                      15.241538
# default payment next month     1.398337
# dtype: float64

# %%
X=df.drop('default payment next month',axis=1)
y=df['default payment next month']

# %%
y.value_counts()
# Out:
# 0    787
# 1    214
# Name: default payment next month, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.10,random_state=42)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((900, 24), (101, 24), (900,), (101,))

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.51713554,  0.08687516, -1.20512077, ..., -0.26091692,
#         -0.2221878 , -0.14820189],
#        [ 0.34892696, -0.89804669, -1.20512077, ..., -0.18630231,
#         -0.31377641, -0.16752541],
#        [-0.8462393 ,  2.58706138,  0.82979235, ...,  0.0226932 ,
#          1.23498702,  2.46252964],
#        ...,
#        [ 1.24616771,  0.2384016 , -1.20512077, ..., -0.22166964,
#         -0.13059919, -0.107088  ],
#        [-0.22613854, -0.67075703,  0.82979235, ...,  2.63412985,
#         -0.20387008, -0.13997911],
#        [-1.3797338 , -0.67075703,  0.82979235, ..., -0.26464765,
#         -0.24355848, -0.16731984]])

# %%
X_test_scaled
# Out:
# array([[ 7.17869586e-02,  3.89928034e-01,  8.29792352e-01, ...,
#         -3.50454448e-01, -1.37254627e-01,  6.10127268e+00],
#        [ 1.52677196e+00,  1.45061310e+00,  8.29792352e-01, ...,
#         -3.02253411e-01, -9.95811774e-02, -2.09872710e-01],
#        [ 8.33921962e-01,  1.11119388e-02, -1.20512077e+00, ...,
#          2.26185892e-02, -8.48103766e-03, -4.30329869e-03],
#        ...,
#        [-1.51483955e+00,  3.14164815e-01,  8.29792352e-01, ...,
#         -3.28070065e-01, -5.42753438e-02, -1.72500191e-01],
#        [ 1.13184746e+00, -1.12533635e+00,  8.29792352e-01, ...,
#         -3.50454448e-01, -3.13776412e-01, -2.09872710e-01],
#        [ 7.50779961e-01, -1.20109956e+00, -1.20512077e+00, ...,
#         -2.38532537e-01, -3.13776412e-01, -1.07088004e-01]])

# %%
plt.plot(X_train,y_train)
# Out:
# [<matplotlib.lines.Line2D at 0x7f26eb542ef0>,
#  <matplotlib.lines.Line2D at 0x7f26eb542dd0>,
#  <matplotlib.lines.Line2D at 0x7f26eb542e00>,
#  <matplotlib.lines.Line2D at 0x7f26eb543fa0>,
#  <matplotlib.lines.Line2D at 0x7f26eb5940d0>,
#  <matplotlib.lines.Line2D at 0x7f26eb5941c0>,
#  <matplotlib.lines.Line2D at 0x7f26eb5942b0>,
#  <matplotlib.lines.Line2D at 0x7f26eb5943a0>,
#  <matplotlib.lines.Line2D at 0x7f26eb594490>,
#  <matplotlib.lines.Line2D at 0x7f26eb594580>,
#  <matplotlib.lines.Line2D at 0x7f26eb542f20>,
#  <matplotlib.lines.Line2D at 0x7f26eb594670>,
#  <matplotlib.lines.Line2D at 0x7f26eb594760>,
#  <matplotlib.lines.Line2D at 0x7f26eb594910>,
#  <matplotlib.lines.Line2D at 0x7f26eb594a00>,
#  <matplotlib.lines.Line2D at 0x7f26eb594af0>,
#  <matplotlib.lines.Line2D at 0x7f26eb594be0>,
#  <matplotlib.lines.Line2D at 0x7f26eb594cd0>,
#  <matplotlib.lines.Line2D at 0x7f26eb594dc0>,
#  <matplotlib.lines.Line2D at 0x7f26eb594eb0>,
#  <matplotlib.lines.Line2D at 0x7f26eb594fa0>,
#  <matplotlib.lines.Line2D at 0x7f26eb595090>,
#  <matplotlib.lines.Line2D at 0x7f26eb595180>,
#  <matplotlib.lines.Line2D at 0x7f26eb595270>]

# %%
plt.plot(X_train_scaled,y_train)
# Out:
# [<matplotlib.lines.Line2D at 0x7f26e32831c0>,
#  <matplotlib.lines.Line2D at 0x7f26e32d0100>,
#  <matplotlib.lines.Line2D at 0x7f26e32d0130>,
#  <matplotlib.lines.Line2D at 0x7f26e32f4fd0>,
#  <matplotlib.lines.Line2D at 0x7f26e32f50c0>,
#  <matplotlib.lines.Line2D at 0x7f26e32f51b0>,
#  <matplotlib.lines.Line2D at 0x7f26e32f52a0>,
#  <matplotlib.lines.Line2D at 0x7f26e32f5390>,
#  <matplotlib.lines.Line2D at 0x7f26e32f5480>,
#  <matplotlib.lines.Line2D at 0x7f26e32f5570>,
#  <matplotlib.lines.Line2D at 0x7f26ec37ef20>,
#  <matplotlib.lines.Line2D at 0x7f26e32f5660>,
#  <matplotlib.lines.Line2D at 0x7f26e32f5750>,
#  <matplotlib.lines.Line2D at 0x7f26e32f5900>,
#  <matplotlib.lines.Line2D at 0x7f26e32f59f0>,
#  <matplotlib.lines.Line2D at 0x7f26e32f5ae0>,
#  <matplotlib.lines.Line2D at 0x7f26e32f5bd0>,
#  <matplotlib.lines.Line2D at 0x7f26e32f5cc0>,
#  <matplotlib.lines.Line2D at 0x7f26e32f5db0>,
#  <matplotlib.lines.Line2D at 0x7f26e32f5ea0>,
#  <matplotlib.lines.Line2D at 0x7f26e32f5f90>,
#  <matplotlib.lines.Line2D at 0x7f26e32f6080>,
#  <matplotlib.lines.Line2D at 0x7f26e32f6170>,
#  <matplotlib.lines.Line2D at 0x7f26e32f6260>]

# %%
plt.plot(X_test_scaled,y_test)
# Out:
# [<matplotlib.lines.Line2D at 0x7f26e34664d0>,
#  <matplotlib.lines.Line2D at 0x7f26e3466530>,
#  <matplotlib.lines.Line2D at 0x7f26e3466560>,
#  <matplotlib.lines.Line2D at 0x7f26e3466650>,
#  <matplotlib.lines.Line2D at 0x7f26e3466740>,
#  <matplotlib.lines.Line2D at 0x7f26e3466830>,
#  <matplotlib.lines.Line2D at 0x7f26e3466920>,
#  <matplotlib.lines.Line2D at 0x7f26e3466a10>,
#  <matplotlib.lines.Line2D at 0x7f26e3466b00>,
#  <matplotlib.lines.Line2D at 0x7f26e3466bf0>,
#  <matplotlib.lines.Line2D at 0x7f26e3466ce0>,
#  <matplotlib.lines.Line2D at 0x7f26e3466500>,
#  <matplotlib.lines.Line2D at 0x7f26e3466dd0>,
#  <matplotlib.lines.Line2D at 0x7f26e3466f80>,
#  <matplotlib.lines.Line2D at 0x7f26e3467070>,
#  <matplotlib.lines.Line2D at 0x7f26e3467160>,
#  <matplotlib.lines.Line2D at 0x7f26e3467250>,
#  <matplotlib.lines.Line2D at 0x7f26e3467340>,
#  <matplotlib.lines.Line2D at 0x7f26e3467430>,
#  <matplotlib.lines.Line2D at 0x7f26e3467520>,
#  <matplotlib.lines.Line2D at 0x7f26e3467610>,
#  <matplotlib.lines.Line2D at 0x7f26e3467700>,
#  <matplotlib.lines.Line2D at 0x7f26e34677f0>,
#  <matplotlib.lines.Line2D at 0x7f26e34678e0>]

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()

# %%
gnb.fit(X_train_scaled,y_train)
# Out:
# GaussianNB()

# %%
y_pred=gnb.predict(X_test)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:402: UserWarning: X has feature names, but GaussianNB was fitted without feature names
#   warnings.warn(

# %%
plt.plot(X_test_scaled,y_pred)
# Out:
# [<matplotlib.lines.Line2D at 0x7f26e332d300>,
#  <matplotlib.lines.Line2D at 0x7f26e34cfb50>,
#  <matplotlib.lines.Line2D at 0x7f26e17c5cf0>,
#  <matplotlib.lines.Line2D at 0x7f26e34cfa30>,
#  <matplotlib.lines.Line2D at 0x7f26e34cfb20>,
#  <matplotlib.lines.Line2D at 0x7f26e34cd150>,
#  <matplotlib.lines.Line2D at 0x7f26e17c5fc0>,
#  <matplotlib.lines.Line2D at 0x7f26e17c60b0>,
#  <matplotlib.lines.Line2D at 0x7f26e17c61a0>,
#  <matplotlib.lines.Line2D at 0x7f26e17c6290>,
#  <matplotlib.lines.Line2D at 0x7f26e332db10>,
#  <matplotlib.lines.Line2D at 0x7f26e17c6380>,
#  <matplotlib.lines.Line2D at 0x7f26e17c6470>,
#  <matplotlib.lines.Line2D at 0x7f26e17c6620>,
#  <matplotlib.lines.Line2D at 0x7f26e17c4cd0>,
#  <matplotlib.lines.Line2D at 0x7f26e17c66e0>,
#  <matplotlib.lines.Line2D at 0x7f26e17c67d0>,
#  <matplotlib.lines.Line2D at 0x7f26e17c68c0>,
#  <matplotlib.lines.Line2D at 0x7f26e17c69b0>,
#  <matplotlib.lines.Line2D at 0x7f26e17c6aa0>,
#  <matplotlib.lines.Line2D at 0x7f26e17c6b90>,
#  <matplotlib.lines.Line2D at 0x7f26e17c6c80>,
#  <matplotlib.lines.Line2D at 0x7f26e17c6d70>,
#  <matplotlib.lines.Line2D at 0x7f26e17c6e60>]

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.4158415841584158
# [[31 52]
#  [ 7 11]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.37      0.51        83
#            1       0.17      0.61      0.27        18
#
#     accuracy                           0.42       101
#    macro avg       0.50      0.49      0.39       101
# weighted avg       0.70      0.42      0.47       101

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()

# %%
rfc.fit(X_train_scaled,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rfc=rfc.predict(X_test)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:402: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %%
plt.plot(X_test_scaled,y_pred_rfc)
# Out:
# [<matplotlib.lines.Line2D at 0x7f26e0c12620>,
#  <matplotlib.lines.Line2D at 0x7f26e18434f0>,
#  <matplotlib.lines.Line2D at 0x7f26e18432b0>,
#  <matplotlib.lines.Line2D at 0x7f26e18433a0>,
#  <matplotlib.lines.Line2D at 0x7f26e0c127a0>,
#  <matplotlib.lines.Line2D at 0x7f26e0c12890>,
#  <matplotlib.lines.Line2D at 0x7f26e0c12980>,
#  <matplotlib.lines.Line2D at 0x7f26e0c12a70>,
#  <matplotlib.lines.Line2D at 0x7f26e0c12b60>,
#  <matplotlib.lines.Line2D at 0x7f26e0c12c50>,
#  <matplotlib.lines.Line2D at 0x7f26e0c12d40>,
#  <matplotlib.lines.Line2D at 0x7f26e0c12650>,
#  <matplotlib.lines.Line2D at 0x7f26e0c12e30>,
#  <matplotlib.lines.Line2D at 0x7f26e0c12fe0>,
#  <matplotlib.lines.Line2D at 0x7f26e0c130d0>,
#  <matplotlib.lines.Line2D at 0x7f26e0c10520>,
#  <matplotlib.lines.Line2D at 0x7f26e0c13220>,
#  <matplotlib.lines.Line2D at 0x7f26e0c13310>,
#  <matplotlib.lines.Line2D at 0x7f26e0c13400>,
#  <matplotlib.lines.Line2D at 0x7f26e0c134f0>,
#  <matplotlib.lines.Line2D at 0x7f26e0c135e0>,
#  <matplotlib.lines.Line2D at 0x7f26e0c136d0>,
#  <matplotlib.lines.Line2D at 0x7f26e0c137c0>,
#  <matplotlib.lines.Line2D at 0x7f26e0c138b0>]

# %%
print(accuracy_score(y_test,y_pred_rfc))
print(confusion_matrix(y_test,y_pred_rfc))
print(classification_report(y_test,y_pred_rfc))
# Out:
# 0.7029702970297029
# [[68 15]
#  [15  3]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        83
#            1       0.17      0.17      0.17        18
#
#     accuracy                           0.70       101
#    macro avg       0.49      0.49      0.49       101
# weighted avg       0.70      0.70      0.70       101

# %%
from sklearn.model_selection import GridSearchCV

# %%
params={'max_depth':[10,12],
        'criterion': ['gini', 'entropy'],
        'n_estimators' :[20,100,150],
        'max_features':['sqrt', 'log2']
}

# %%
rfc=RandomForestClassifier()

# %%
cv=GridSearchCV(rfc,param_grid=params,cv=5,verbose=3)

# %%
cv
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 12],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [20, 100, 150]},
#              verbose=3)

# %%
cv.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=20;, score=0.811 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=20;, score=0.767 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=20;, score=0.811 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=20;, score=0.833 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=20;, score=0.756 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.811 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.778 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.817 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.806 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.756 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.800 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.789 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.806 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.817 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.750 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=20;, score=0.783 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=20;, score=0.778 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=20;, score=0.811 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=20;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=20;, score=0.772 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100;, score=0.800 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100;, score=0.783 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100;, score=0.811 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100;, score=0.817 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100;, score=0.761 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=150;, score=0.806 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=150;, score=0.772 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=150;, score=0.817 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=150;, score=0.822 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=150;, score=0.756 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=20;, score=0.783 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=20;, score=0.789 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=20;, score=0.800 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=20;, score=0.783 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=20;, score=0.739 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.806 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.783 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.828 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.822 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.744 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=150;, score=0.800 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=150;, score=0.772 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=150;, score=0.817 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=150;, score=0.828 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=150;, score=0.750 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=20;, score=0.783 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=20;, score=0.783 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=20;, score=0.778 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=20;, score=0.806 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=20;, score=0.739 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=100;, score=0.817 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=100;, score=0.794 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=100;, score=0.817 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=100;, score=0.800 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=100;, score=0.761 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=150;, score=0.800 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=150;, score=0.783 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=150;, score=0.817 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=150;, score=0.822 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=12, max_features=log2, n_estimators=150;, score=0.750 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=20;, score=0.778 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=20;, score=0.789 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=20;, score=0.789 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=20;, score=0.806 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=20;, score=0.778 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.800 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.783 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.811 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.811 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.772 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.811 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.783 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.806 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.822 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.756 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=20;, score=0.778 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=20;, score=0.772 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=20;, score=0.811 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=20;, score=0.806 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=20;, score=0.744 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100;, score=0.806 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100;, score=0.778 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100;, score=0.822 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100;, score=0.822 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=100;, score=0.767 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=150;, score=0.800 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=150;, score=0.783 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=150;, score=0.822 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=150;, score=0.822 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=150;, score=0.756 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=20;, score=0.811 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=20;, score=0.783 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=20;, score=0.833 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=20;, score=0.772 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=20;, score=0.772 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.806 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.783 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.811 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.833 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.767 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=150;, score=0.806 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=150;, score=0.772 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=150;, score=0.811 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=150;, score=0.811 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=150;, score=0.761 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=20;, score=0.800 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=20;, score=0.761 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=20;, score=0.800 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=20;, score=0.811 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=20;, score=0.750 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=100;, score=0.800 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=100;, score=0.772 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=100;, score=0.822 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=100;, score=0.806 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=100;, score=0.750 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=150;, score=0.800 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=150;, score=0.783 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=150;, score=0.822 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=150;, score=0.800 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=12, max_features=log2, n_estimators=150;, score=0.761 total time=   0.6s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 12],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [20, 100, 150]},
#              verbose=3)

# %%
cv.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=12)

# %%
cv.best_index_
# Out:
# 19

# %%
cv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 12,
#  'max_features': 'sqrt',
#  'n_estimators': 100}

# %%
cv.best_score_
# Out:
# 0.8000000000000002

# %%
y_pred_gsv=cv.predict(X_test_scaled)

# %%
plt.plot(X_test_scaled,y_pred_gsv)
# Out:
# [<matplotlib.lines.Line2D at 0x7f26e0a48190>,
#  <matplotlib.lines.Line2D at 0x7f26e0a4a050>,
#  <matplotlib.lines.Line2D at 0x7f26e0a49f30>,
#  <matplotlib.lines.Line2D at 0x7f26e0a4a500>,
#  <matplotlib.lines.Line2D at 0x7f26e0a48f40>,
#  <matplotlib.lines.Line2D at 0x7f26e0a49540>,
#  <matplotlib.lines.Line2D at 0x7f26e0a49150>,
#  <matplotlib.lines.Line2D at 0x7f26e0a49f00>,
#  <matplotlib.lines.Line2D at 0x7f26e0a48b50>,
#  <matplotlib.lines.Line2D at 0x7f26e0a49390>,
#  <matplotlib.lines.Line2D at 0x7f26e0cba050>,
#  <matplotlib.lines.Line2D at 0x7f26e0cb9c60>,
#  <matplotlib.lines.Line2D at 0x7f26e0cba710>,
#  <matplotlib.lines.Line2D at 0x7f26e0a49630>,
#  <matplotlib.lines.Line2D at 0x7f26e0a49ab0>,
#  <matplotlib.lines.Line2D at 0x7f26e0a48dc0>,
#  <matplotlib.lines.Line2D at 0x7f26e0a4a5f0>,
#  <matplotlib.lines.Line2D at 0x7f26e0a48d90>,
#  <matplotlib.lines.Line2D at 0x7f26e0a49c30>,
#  <matplotlib.lines.Line2D at 0x7f26e0a4a140>,
#  <matplotlib.lines.Line2D at 0x7f26e0a4a860>,
#  <matplotlib.lines.Line2D at 0x7f26e0a4ad10>,
#  <matplotlib.lines.Line2D at 0x7f26e0a4ab30>,
#  <matplotlib.lines.Line2D at 0x7f26e0a48970>]

# %%
print(accuracy_score(y_test,y_pred_gsv))
print(confusion_matrix(y_test,y_pred_gsv))
print(classification_report(y_test,y_pred_gsv))
# Out:
# 0.8217821782178217
# [[80  3]
#  [15  3]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90        83
#            1       0.50      0.17      0.25        18
#
#     accuracy                           0.82       101
#    macro avg       0.67      0.57      0.57       101
# weighted avg       0.78      0.82      0.78       101

# %% [markdown]
# #### For testing on new data

# %%
X_train_scaled[0]
# Out:
# array([-0.51713554,  0.08687516, -1.20512077,  0.28331819, -1.12123361,
#         1.07741295, -0.8585092 ,  0.13291927,  0.13102497,  0.23384824,
#         0.23154616,  0.25259406, -0.29838159, -0.27098277, -0.22337312,
#        -0.16274427, -0.14248654, -0.10810345, -0.31927806, -0.19665795,
#        -0.2942634 , -0.26091692, -0.2221878 , -0.14820189])

# %%
y_train[0]
# Out:
# 0

# %%
# new data prediction
pred1=cv.predict(np.array([[-0.51713554,0.08687516, -1.20512077,  0.28331819, -1.12123361,  1.07741295,
       -0.8585092 ,  0.13291927,  0.13102497,  0.23384824,  0.23154616,
        0.25259406, -0.29838159, -0.27098277, -0.22337312, -0.16274427,
       -0.14248654, -0.10810345, -0.31927806, -0.19665795, -0.2942634 ,
       -0.26091692, -0.2221878 , -0.14820189]]))[0]

# %%
pred1
# Out:
# 0

# %%
import joblib
joblib.dump(cv,'Credit-Card-Fraud-Prediction')
# Out:
# ['Credit-Card-Fraud-Prediction']

# %%
modelccfd=joblib.load('Credit-Card-Fraud-Prediction')

# %%
modelccfd.predict(np.array([[-0.51713554,0.08687516, -1.20512077,  0.28331819, -1.12123361,  1.07741295,
       -0.8585092 ,  0.13291927,  0.13102497,  0.23384824,  0.23154616,
        0.25259406, -0.29838159, -0.27098277, -0.22337312, -0.16274427,
       -0.14248654, -0.10810345, -0.31927806, -0.19665795, -0.2942634 ,
       -0.26091692, -0.2221878 , -0.14820189]]))[0]
# Out:
# 0
